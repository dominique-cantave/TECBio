# %%
from actual_work import *
import sys

stockset = sys.argv[1]
stockyear = stockset.split(os.path.sep)[-1].split('_')[2][0:4]
indexset = sys.argv[2]
indexname = indexset.split(os.path.sep)[-1].split('_')[0]

new_df, stkyr, idxname, dates = reform_data(stockset, indexset)

correlations = correlations(dates, new_df)

networks(correlations, indexname, stockyear, show_network=True)
# Out:
# ImportErrorTraceback (most recent call last)
# <ipython-input-1-5e2a45736244> in <module>()
# ----> 1 from actual_work import *
#       2 import sys
#       3
#       4 stockset = sys.argv[1]
#       5 stockyear = stockset.split(os.path.sep)[-1].split('_')[2][0:4]
#
# ImportError: No module named actual_work

# %%
import itertools

before = [1, 8, 13]
after = [5, 11]
for i in itertools.izip_longest(before,after): print i
# Out:
# (1, 5)
# (8, 11)
# (13, None)

# %%
import os
import pandas as pd
import numpy as np

stks = 'stocks_from_2018.csv'
idx = 'SP_constituents.csv'

stockyear = stks.split(os.path.sep)[-1].split('_')[2][0:4]
indexname = idx.split(os.path.sep)[-1].split('_')[0]

# reading / organizing the datasets
stockslist = pd.read_csv(stks)
dates = stockslist['date'].unique()

index = pd.read_csv(idx)
index = index.set_index(['co_tic'])
index.sort_index(level='from',inplace=True)

indexlist = stockslist[stockslist['TICKER'].isin(index.index.values)]
indexlist = indexlist.set_index(['TICKER', 'date'])
indexlist = indexlist[~indexlist.index.duplicated(keep='last')]
stocks = np.unique(indexlist.index.get_level_values(0))
stocks = stocks[~pd.isnull(stocks)]

stocks
# Out:
# array(['A', 'AA', 'AABA', 'AAL', 'AAP', 'AAPL', 'ABBV', 'ABC', 'ABMD',
#        'ABT', 'ABX', 'ACN', 'ADBE', 'ADI', 'ADM', 'ADNT', 'ADP', 'ADS',
#        'ADSK', 'AEE', 'AEP', 'AES', 'AET', 'AFL', 'AGN', 'AIG', 'AIV',
#        'AIZ', 'AJG', 'AKAM', 'AKS', 'ALB', 'ALGN', 'ALK', 'ALL', 'ALLE',
#        'ALXN', 'AMAT', 'AMBC', 'AMD', 'AME', 'AMG', 'AMGN', 'AMP', 'AMT',
#        'AMZN', 'AN', 'ANDV', 'ANF', 'ANSS', 'ANTM', 'AON', 'AOS', 'APA',
#        'APC', 'APD', 'APH', 'APTV', 'ARE', 'ARNC', 'ASA', 'ASH', 'ASIX',
#        'ATGE', 'ATI', 'ATUS', 'ATVI', 'AVB', 'AVGO', 'AVP', 'AVY', 'AWK',
#        'AXP', 'AYI', 'AZO', 'BA', 'BAC', 'BAX', 'BBBY', 'BBT', 'BBY',
#        'BC', 'BCO', 'BDX', 'BEN', 'BGG', 'BHF', 'BHGE', 'BIG', 'BIIB',
#        'BIVV', 'BK', 'BKNG', 'BLK', 'BLL', 'BMS', 'BMY', 'BR', 'BSET',
#        'BSX', 'BTU', 'BVSN', 'BWA', 'BXP', 'C', 'CA', 'CAG', 'CAH', 'CAL',
#        'CAR', 'CARS', 'CAT', 'CB', 'CBOE', 'CBRE', 'CBS', 'CCE', 'CCI',
#        'CCK', 'CCL', 'CDNS', 'CELG', 'CERN', 'CF', 'CFG', 'CHD', 'CHK',
#        'CHRW', 'CHTR', 'CI', 'CIEN', 'CINF', 'CIT', 'CL', 'CLF', 'CLX',
#        'CMA', 'CMCSA', 'CME', 'CMG', 'CMI', 'CMS', 'CNA', 'CNC', 'CNDT',
#        'CNO', 'CNP', 'CNX', 'COF', 'COG', 'COL', 'COO', 'COP', 'COST',
#        'COTY', 'CP', 'CPB', 'CPN', 'CR', 'CRM', 'CSCO', 'CSRA', 'CSX',
#        'CTAS', 'CTB', 'CTL', 'CTSH', 'CTXS', 'CVG', 'CVS', 'CVX', 'CW',
#        'CXO', 'CZR', 'D', 'DAL', 'DAN', 'DDR', 'DDS', 'DE', 'DF', 'DFS',
#        'DG', 'DGX', 'DHI', 'DHR', 'DIS', 'DISCA', 'DISH', 'DLPH', 'DLR',
#        'DLTR', 'DLX', 'DNB', 'DNR', 'DO', 'DOV', 'DPS', 'DRE', 'DRI',
#        'DTE', 'DUK', 'DVA', 'DVN', 'DWDP', 'DXC', 'DYN', 'EA', 'EBAY',
#        'ECL', 'ED', 'EFX', 'EHC', 'EIX', 'EL', 'EME', 'EMN', 'EMR',
#        'ENDP', 'EOG', 'EQIX', 'EQR', 'EQT', 'ES', 'ESRX', 'ESS', 'ESV',
#        'ETFC', 'ETN', 'ETR', 'EVHC', 'EW', 'EXC', 'EXPD', 'EXPE', 'EXR',
#        'F', 'FAST', 'FB', 'FBHS', 'FCPT', 'FCX', 'FDC', 'FDX', 'FE',
#        'FFIV', 'FHN', 'FII', 'FIS', 'FISV', 'FITB', 'FL', 'FLIR', 'FLR',
#        'FLS', 'FLT', 'FMC', 'FOSL', 'FOXA', 'FRT', 'FSLR', 'FTI', 'FTR',
#        'FTV', 'GCO', 'GD', 'GE', 'GGP', 'GHC', 'GILD', 'GIS', 'GLW', 'GM',
#        'GME', 'GNW', 'GOOGL', 'GPC', 'GPN', 'GPS', 'GRA', 'GRMN', 'GS',
#        'GT', 'GWW', 'HAL', 'HAS', 'HBAN', 'HBI', 'HCA', 'HCP', 'HD',
#        'HES', 'HFC', 'HIG', 'HII', 'HLT', 'HOG', 'HOLX', 'HON', 'HP',
#        'HPE', 'HPQ', 'HRB', 'HRL', 'HRS', 'HSIC', 'HST', 'HSY', 'HUM',
#        'IAC', 'IBM', 'ICE', 'IDA', 'IDXX', 'IFF', 'ILMN', 'INCY', 'INFO',
#        'INTC', 'INTU', 'IP', 'IPG', 'IPGP', 'IQV', 'IR', 'IRM', 'ISRG',
#        'IT', 'ITT', 'ITW', 'IVZ', 'JBGS', 'JBHT', 'JBL', 'JCI', 'JCP',
#        'JEC', 'JNJ', 'JNPR', 'JPM', 'JWN', 'K', 'KBH', 'KEY', 'KHC',
#        'KIM', 'KLAC', 'KMB', 'KMI', 'KMX', 'KO', 'KODK', 'KORS', 'KR',
#        'KSS', 'KSU', 'L', 'LB', 'LDOS', 'LEG', 'LEN', 'LH', 'LKQ', 'LLL',
#        'LLY', 'LM', 'LMT', 'LNC', 'LNT', 'LOW', 'LPX', 'LRCX', 'LUB',
#        'LUV', 'LW', 'LYB', 'M', 'MA', 'MAA', 'MAC', 'MAR', 'MAS', 'MAT',
#        'MBI', 'MCD', 'MCHP', 'MCK', 'MCO', 'MDLZ', 'MDP', 'MDR', 'MDT',
#        'MET', 'MGI', 'MGM', 'MHK', 'MKC', 'MLI', 'MLM', 'MMC', 'MMM',
#        'MNK', 'MNST', 'MO', 'MON', 'MOS', 'MPC', 'MRK', 'MRO', 'MS',
#        'MSCI', 'MSFT', 'MSI', 'MSN', 'MTB', 'MTD', 'MTG', 'MTW', 'MU',
#        'MUR', 'MXIM', 'MYL', 'NAV', 'NAVI', 'NBL', 'NBR', 'NC', 'NCLH',
#        'NCR', 'NDAQ', 'NE', 'NEE', 'NEM', 'NEU', 'NFG', 'NFLX', 'NFX',
#        'NGVT', 'NI', 'NKE', 'NKTR', 'NL', 'NLSN', 'NOC', 'NOV', 'NRG',
#        'NSC', 'NTAP', 'NTRS', 'NUE', 'NVDA', 'NWL', 'NWSA', 'NYT', 'O',
#        'OC', 'ODP', 'OI', 'OKE', 'OLN', 'OMC', 'ORCL', 'ORLY', 'OXY',
#        'PAYX', 'PBCT', 'PBI', 'PCAR', 'PCG', 'PCH', 'PDCO', 'PEG', 'PEP',
#        'PFE', 'PFG', 'PG', 'PGR', 'PH', 'PHM', 'PKG', 'PKI', 'PLD', 'PM',
#        'PNC', 'PNR', 'PNW', 'PPG', 'PPL', 'PRGO', 'PRI', 'PRU', 'PSA',
#        'PSX', 'PTC', 'PVH', 'PWR', 'PX', 'PXD', 'PYPL', 'QCOM', 'QCP',
#        'QEP', 'QRVO', 'R', 'RAD', 'RCL', 'RDC', 'RE', 'REG', 'REGN', 'RF',
#        'RHI', 'RHT', 'RIG', 'RJF', 'RL', 'RLGY', 'RMD', 'ROK', 'ROP',
#        'ROST', 'RRC', 'RRD', 'RSG', 'RTN', 'RYI', 'S', 'SANM', 'SBAC',
#        'SBUX', 'SCG', 'SCHW', 'SCI', 'SEE', 'SHLD', 'SHW', 'SIG', 'SIVB',
#        'SJM', 'SLB', 'SLG', 'SNA', 'SNI', 'SNPS', 'SNV', 'SO', 'SPG',
#        'SPGI', 'SPXC', 'SR', 'SRCL', 'SRE', 'SSP', 'STI', 'STT', 'STX',
#        'STZ', 'SVU', 'SWK', 'SWKS', 'SWN', 'SYF', 'SYK', 'SYMC', 'SYY',
#        'T', 'TAP', 'TDC', 'TDG', 'TEL', 'TEN', 'TER', 'TEX', 'TGNA',
#        'TGT', 'THC', 'TIF', 'TJX', 'TKR', 'TMK', 'TMO', 'TPR', 'TRCO',
#        'TRIP', 'TROW', 'TRV', 'TSCO', 'TSN', 'TSS', 'TTWO', 'TUP', 'TWTR',
#        'TWX', 'TXN', 'TXT', 'UAA', 'UAL', 'UDR', 'UHS', 'UIS', 'ULTA',
#        'UN', 'UNH', 'UNM', 'UNP', 'UPS', 'URBN', 'URI', 'USB', 'USG',
#        'UTX', 'V', 'VAR', 'VC', 'VFC', 'VIAB', 'VIAV', 'VLO', 'VMC',
#        'VNO', 'VREX', 'VRSK', 'VRSN', 'VRTX', 'VSM', 'VTR', 'VZ', 'WAT',
#        'WBA', 'WDC', 'WEC', 'WEN', 'WFC', 'WFT', 'WGL', 'WHR', 'WIN',
#        'WLTW', 'WM', 'WMB', 'WMT', 'WOR', 'WPX', 'WRK', 'WU', 'WY',
#        'WYNN', 'X', 'XEC', 'XEL', 'XL', 'XLNX', 'XOM', 'XRAY', 'XRX',
#        'XYL', 'YRCW', 'YUM', 'YUMC', 'ZBH', 'ZION', 'ZTS'], dtype=object)

# %%
from itertools import *

new_df = pd.DataFrame(index=stocks) # new df for storing price information
for stock in stocks:

    # creates list of ranges corresponding to dates that the stock was in the index
    # if stock was removed and added again, ranges has more than 1 element
    fromdate = as_list(index.at[stock,'from'])
    thrudate = as_list(index.at[stock,'thru'])
    ranges = list(izip_longest(fromdate,thrudate))

    # considers only the dates within these ranges
    for ran in ranges:
        for date in indexlist.loc[stock].index.values:
            # makes sure to only account for dates since it was added
            if date >= ran[0]:
                # and only go until the date removed if applicable
                if np.isnan(ran[-1]) or date <= ran[-1]:
                    new_df.at[stock, date] = indexlist.at[(stock,date),'PRC']

new_df = new_df.dropna(how='all') 
new_df = new_df.T
new_df.loc[20180105, 'BA'] = None
new_df = new_df.pct_change() 
dates = np.sort(new_df.index.unique())
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
# Out:
# Int64Index([20180102, 20180103, 20180104, 20180105, 20180108, 20180109,
#             20180110, 20180111, 20180112, 20180116, 20180117, 20180118,
#             20180119, 20180122, 20180123, 20180124, 20180125, 20180126,
#             20180129, 20180130, 20180131, 20180201, 20180202, 20180205,
#             20180206, 20180207, 20180208, 20180209, 20180212, 20180213,
#             20180214, 20180215, 20180216, 20180220, 20180221, 20180222,
#             20180223, 20180226, 20180227, 20180228, 20180301, 20180302,
#             20180305, 20180306, 20180307, 20180308, 20180309, 20180312,
#             20180313, 20180314, 20180315, 20180316, 20180319, 20180320,
#             20180321, 20180322, 20180323, 20180326, 20180327, 20180328,
#             20180329],
#            dtype='int64')

# %%
def as_list(x):
    if type(x) is np.ndarray:
        return x.tolist()
    else:
        return [x]

# %%
value = False
value = not value
value
# Out:
# True

# %%
0 == None
# Out:
# False
